# %%
import pandas as pd

# %%
customer_den = pd.read_excel("KPMG_VI_New_raw_data_update_final copy.xlsx",sheet_name=3,skiprows=1)

# %%
transaction = pd.read_excel("KPMG_VI_New_raw_data_update_final copy.xlsx",sheet_name=2,skiprows=1)

# %%
addr = pd.read_excel("KPMG_VI_New_raw_data_update_final copy.xlsx",sheet_name=4,skiprows=1)

# %%
customer_den.head()
# Out:
#   customer_id      first_name  last_name  gender  \
# 0           1         Laraine  Medendorp  Female
# 1           2             Eli    Bockman    Male
# 2           3           Arlin     Dearle    Male
# 3           4          Talbot        NaN    Male
# 4           5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases                  DOB        AGE  \
# 0                                 93.0  1953-10-12 00:00:00  68.368973
# 1                                 81.0  1980-12-16 00:00:00  41.171713
# 2                                 61.0  1954-01-20 00:00:00  68.095001
# 3                                 33.0  1961-10-03 00:00:00  60.388152
# 4                                 56.0  1977-05-13 00:00:00  44.768973
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# ...

# %%
transaction.head()
# Out:
#   transaction_id  product_id  customer_id     transaction_date  online_order  \
# 0              1         2.0       2950.0  2017-02-25 00:00:00           0.0
# 1              2         3.0       3120.0  2017-05-21 00:00:00           1.0
# 2              3        37.0        402.0  2017-10-16 00:00:00           0.0
# 3              4        88.0       3135.0  2017-08-31 00:00:00           0.0
# 4              5        78.0        787.0  2017-10-01 00:00:00           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date  \
# ...

# %%
addr.head()
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
# 2            4   0 Holy Cross Court      4211   QLD  Australia
# 3            5  17979 Del Mar Point      2448   NSW  Australia
# 4            6     9 Oakridge Court      3216   VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
# Count unique customer IDs

# %%
customer_den['customer_id'].nunique() #one extra line(last line for summary data)
# Out:
# 4001

# %%
transaction['customer_id'].nunique()
# Out:
# 3495

# %%
#addr['customer_id'].duplicated(subset='customer_id', keep='first')
addr['customer_id'].nunique()
# Out:
# 3999

# %%
# People who made 99 purchase past three years
customer_den[customer_den['past_3_years_bike_related_purchases'] == 99]
# Out:
#      customer_id first_name   last_name  gender  \
# 10            11      Uriah      Bisatt    Male
# 157          158     Hamlin       Odams    Male
# 172          173       Ebba  Hanselmann  Female
# 181          182      Lydon     Dahlman    Male
# 226          227    Wendall     McKeand    Male
# 285          286      Kiley      Canaan    Male
# 380          381      Leesa   Castleman  Female
# 554          555      Jarib      Senior    Male
# 560          561      Karin     Burkill  Female
# 757          758      Teena      Birrel  Female
# 793          794      Scott   Ommundsen    Male
# 1047        1048     Braden     Lamming    Male
# 1097        1098      Maure        Crow  Female
# 1131        1132     Coriss     Darkott  Female
# 1281        1282     Garald      Pidler    Male
# 1363        1364      Selby     Cabbell    Male
# 1379        1380     Lavina      Clavey  Female
# 1451        1452    Zachery      Hamber    Male
# ...

# %%
# How many orders have they made from the company
len(transaction[transaction['customer_id']==11])
# Out:
# 6

# %%
# People who made 0 purchase past three years
customer_den[customer_den['past_3_years_bike_related_purchases'] == 0]
# Out:
#        customer_id  first_name    last_name  gender  \
# 278            279      Tamera      Hinckes  Female
# 309            310     Myranda      Clowser  Female
# 427            428      Freida       Everil  Female
# 459            460        Illa          NaN  Female
# 474            475      Vernor          NaN    Male
# 485            486       Prudi         Edon  Female
# 571            572  Clementius   Everington    Male
# 601            602      Lebbie        Bruck  Female
# 928            929       Kippy    Conerding    Male
# 980            981         Bud    Smittoune    Male
# 1015          1016      Adrian  Prettyjohns    Male
# 1041          1042      Isacco     Woodwind    Male
# 1045          1046        Shir      Clevely  Female
# 1194          1195        Ally     Folliott  Female
# 1213          1214     Martino     Shalcros    Male
# 1290          1291      Warner        Zuker    Male
# 1299          1300      Sisely   Strelitzer  Female
# ...

# %%
# How many orders have they made from the company
transaction[transaction['customer_id']==279]
# Out:
#       transaction_id  product_id  customer_id     transaction_date  \
# 1785            1786        70.0        279.0  2017-05-03 00:00:00
# 4149            4150         6.0        279.0  2017-01-30 00:00:00
# 7918            7919        66.0        279.0  2017-02-01 00:00:00
# 10743          10744        88.0        279.0  2017-12-16 00:00:00
# 15366          15367        54.0        279.0  2017-05-17 00:00:00
# 15914          15915        19.0        279.0  2017-06-22 00:00:00
#
#        online_order order_status           brand product_line product_class  \
# 1785            1.0     Approved   Trek Bicycles     Standard          high
# 4149            1.0     Approved      OHM Cycles     Standard          high
# 7918            0.0     Approved  Giant Bicycles         Road           low
# 10743           0.0     Approved  Norco Bicycles     Standard        medium
# 15366           1.0     Approved        WeareA2B     Standard        medium
# ...
